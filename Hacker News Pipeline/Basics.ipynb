# %% [markdown]
# <h1 style='text-align:center'>Analysing Hacker News Data <h1>

# %%
from pipeline import Pipeline
pipeline = Pipeline()

# %% [markdown]
# > ## File to JSON

# %%
import json
@pipeline.task()
def file_to_json():
    file = open('hn_stories_2014.json', mode='r')
    json_file = json.loads(file.read())
    return json_file['stories']

# %%
output = pipeline.run()

# %% [markdown]
# ## First 5 stories from 2014 files

# %%
output[list(output.keys())[0]][:5]
# Out:
# [{'story_text': '',
#   'created_at': '2014-05-29T08:25:40Z',
#   'story_title': None,
#   'story_id': None,
#   'comment_text': None,
#   'created_at_i': 1401351940,
#   'url': 'https://duckduckgo.com/settings',
#   'parent_id': None,
#   'objectID': '7815290',
#   'author': 'TuxLyn',
#   'points': 1,
#   'title': 'DuckDuckGo Settings',
#   '_tags': ['story', 'author_TuxLyn', 'story_7815290'],
#   'num_comments': 0,
#   '_highlightResult': {'story_text': {'matchedWords': [],
#     'value': '',
#     'matchLevel': 'none'},
#    'author': {'matchedWords': [], 'value': 'TuxLyn', 'matchLevel': 'none'},
#    'url': {'matchedWords': [],
#     'value': 'https://duckduckgo.com/settings',
#     'matchLevel': 'none'},
#    'title': {'matchedWords': [],
#     'value': 'DuckDuckGo Settings',
#     'matchLevel': 'none'}},
#   'story_url': None},
#  {'story_text': '',
#   'created_at': '2014-05-29T08:23:46Z',
#   'story_title': None,
#   'story_id': None,
#   'comment_text': None,
#   'created_at_i': 1401351826,
#   'url': 'http://bits.blogs.nytimes.com/2014/05/28/making-twitter-easier-to-use/',
#   'parent_id': None,
#   'objectID': '7815285',
#   'author': 'Leynos',
#   'points': 1,
#   'title': 'Making Twitter Easier to Use',
#   '_tags': ['story', 'author_Leynos', 'story_7815285'],
#   'num_comments': 0,
#   '_highlightResult': {'story_text': {'matchedWords': [],
#     'value': '',
#     'matchLevel': 'none'},
#    'author': {'matchedWords': [], 'value': 'Leynos', 'matchLevel': 'none'},
#    'url': {'matchedWords': [],
#     'value': 'http://bits.blogs.nytimes.com/2014/05/28/making-twitter-easier-to-use/',
#     'matchLevel': 'none'},
#    'title': {'matchedWords': [],
#     'value': 'Making Twitter Easier to Use',
#     'matchLevel': 'none'}},
#   'story_url': None},
#  {'story_text': '',
#   'created_at': '2014-05-29T08:21:56Z',
#   'story_title': None,
#   'story_id': None,
#   'comment_text': None,
#   'created_at_i': 1401351716,
#   'url': 'http://www.bbc.co.uk/news/technology-27617079',
#   'parent_id': None,
#   'objectID': '7815279',
#   'author': 'darrhiggs',
#   'points': 2,
#   'title': 'London refers Uber app row to High Court',
#   '_tags': ['story', 'author_darrhiggs', 'story_7815279'],
#   'num_comments': 0,
#   '_highlightResult': {'story_text': {'matchedWords': [],
#     'value': '',
#     'matchLevel': 'none'},
#    'author': {'matchedWords': [], 'value': 'darrhiggs', 'matchLevel': 'none'},
#    'url': {'matchedWords': [],
#     'value': 'http://www.bbc.co.uk/news/technology-27617079',
#     'matchLevel': 'none'},
#    'title': {'matchedWords': [],
#     'value': 'London refers Uber app row to High Court',
#     'matchLevel': 'none'}},
#   'story_url': None},
#  {'story_text': '',
#   'created_at': '2014-05-29T08:18:42Z',
#   'story_title': None,
#   'story_id': None,
#   'comment_text': None,
#   'created_at_i': 1401351522,
#   'url': 'http://nomination.younggloballeaders.org/nominationform.aspx',
#   'parent_id': None,
#   'objectID': '7815274',
#   'author': 'a159482a',
#   'points': 1,
#   'title': ' Young Global Leaders, who should be nominated? (World Economic Forum)',
#   '_tags': ['story', 'author_a159482a', 'story_7815274'],
#   'num_comments': 1,
#   '_highlightResult': {'story_text': {'matchedWords': [],
#     'value': '',
#     'matchLevel': 'none'},
#    'author': {'matchedWords': [], 'value': 'a159482a', 'matchLevel': 'none'},
#    'url': {'matchedWords': [],
#     'value': 'http://nomination.younggloballeaders.org/nominationform.aspx',
#     'matchLevel': 'none'},
#    'title': {'matchedWords': [],
#     'value': ' Young Global Leaders, who should be nominated? (World Economic Forum)',
#     'matchLevel': 'none'}},
#   'story_url': None},
#  {'story_text': '',
#   'created_at': '2014-05-29T08:17:30Z',
#   'story_title': None,
#   'story_id': None,
#   'comment_text': None,
#   'created_at_i': 1401351450,
#   'url': 'https://blooki.st',
#   'parent_id': None,
#   'objectID': '7815273',
#   'author': 'johngorse',
#   'points': 1,
#   'title': 'Blooki.st goes BETA in a few hours',
#   '_tags': ['story', 'author_johngorse', 'story_7815273'],
#   'num_comments': 0,
#   '_highlightResult': {'story_text': {'matchedWords': [],
#     'value': '',
#     'matchLevel': 'none'},
#    'author': {'matchedWords': [], 'value': 'johngorse', 'matchLevel': 'none'},
#    'url': {'matchedWords': [],
#     'value': 'https://blooki.st',
#     'matchLevel': 'none'},
#    'title': {'matchedWords': [],
#     'value': 'Blooki.st goes BETA in a few hours',
#     'matchLevel': 'none'}},
#   'story_url': None}]

# %% [markdown]
# > ## Filter Stories

# %%
@pipeline.task(depends_on=file_to_json)
def filter_stories(stories):
    filtered_stories = (story for story in stories if story['points'] > 50 \
                       and story['num_comments'] > 1 and \
                        not str.lower(story['title']).startswith('ask hn'))
    return filtered_stories

# %%
output = pipeline.run()

# %% [markdown]
# ## First 2 filtered(popular) stories from 2014 files

# %%
for x in range(2):
    print('STORY {}:'.format(x), next(output[list(output.keys())[1]]))
# Out:
# STORY 0: {'story_text': '', 'created_at': '2014-05-28T20:50:28Z', 'story_title': None, 'story_id': None, 'comment_text': None, 'created_at_i': 1401310228, 'url': 'http://action.sumofus.org/a/Facebook-app-taps-phones/', 'parent_id': None, 'objectID': '7812812', 'author': 'makmanalp', 'points': 54, 'title': 'Facebook: Do not release your new app feature that listens to users', '_tags': ['story', 'author_makmanalp', 'story_7812812'], 'num_comments': 23, '_highlightResult': {'story_text': {'matchedWords': [], 'value': '', 'matchLevel': 'none'}, 'author': {'matchedWords': [], 'value': 'makmanalp', 'matchLevel': 'none'}, 'url': {'matchedWords': [], 'value': 'http://action.sumofus.org/a/Facebook-app-taps-phones/', 'matchLevel': 'none'}, 'title': {'matchedWords': [], 'value': 'Facebook: Do not release your new app feature that listens to users', 'matchLevel': 'none'}}, 'story_url': None}
# STORY 1: {'story_text': '', 'created_at': '2014-05-28T20:32:33Z', 'story_title': None, 'story_id': None, 'comment_text': None, 'created_at_i': 1401309153, 'url': 'http://www.nytimes.com/2014/05/29/technology/apple-confirms-its-3-billion-deal-for-beats-electronics.html?src=twr&_r=0', 'parent_id': None, 'objectID': '7812677', 'author': 'bedhead', 'points': 284, 'title': 'Apple Confirms Its $3 Billion Deal for Beats Electronics', '_tags': ['story', 'author_bedhead', 'story_7812677'], 'num_comments': 311, '_highlightResult': {'story_text': {'matchedWords': [], 'value': '', 'matchLevel': 'none'}, 'author': {'matchedWords': [], 'value': 'bedhead', 'matchLevel': 'none'}, 'url': {'matchedWords': [], 'value': 'http://www.nytimes.com/2014/05/29/technology/apple-confirms-its-3-billion-deal-for-beats-electronics.html?src=twr&_r=0', 'matchLevel': 'none'}, 'title': {'matchedWords': [], 'value': 'Apple Confirms Its $3 Billion Deal for Beats Electronics', 'matchLevel': 'none'}}, 'story_url': None}

# %% [markdown]
# > ## Filter stories to CSV

# %%
from pipeline import build_csv
import io, datetime

# %%
@pipeline.task(depends_on=filter_stories)
def json_to_csv(filtered_stories):
    lines=[]
    for line in filtered_stories:
        lines.append((line['objectID'],\
                      datetime.datetime.strptime(
                          line['created_at']\
                          ,'%Y-%m-%dT%H:%M:%SZ'),
                      line['url'],\
                      line['points'],\
                      line['title']\
                     ))
        
    file = build_csv(lines,
                     header=['objectID', 'created_at', 'url'\
                             , 'points', 'title'],
                     file=io.StringIO()
                    )
    return file

# %%
output = pipeline.run()

# %% [markdown]
# ## First 2 lines from the filtered popular file

# %%
for x in range(3):
    print('STORY {}:'.format(x), next(output[list(output.keys())[2]]))
# Out:
# STORY 0: objectID,created_at,url,points,title
#
# STORY 1: 7814725,2014-05-29 04:27:42,http://krebsonsecurity.com/2014/05/true-goodbye-using-truecrypt-is-not-secure/,60,True Goodbye: ‘Using TrueCrypt Is Not Secure’
#
# STORY 2: 7814608,2014-05-29 03:51:01,http://projects.aljazeera.com/2014/portrait-of-down-syndrome/index.html,161,For Hire: Dedicated Young Man With Down Syndrome

# %% [markdown]
# > ## Extract Titles

# %%
import csv
@pipeline.task(depends_on=json_to_csv)
def extract_titles(csv_file):
    reader = csv.reader(csv_file)
    header = next(reader)
    idx = header.index('title')

    for line in reader:
        yield line[idx]

# %%
output = pipeline.run()

# %% [markdown]
# ## First 3 popular titles from the file

# %%
for x in range(3):
    print('STORY {}:'.format(x), next(output[list(output.keys())[3]]))
# Out:
# STORY 0: True Goodbye: ‘Using TrueCrypt Is Not Secure’
# STORY 1: For Hire: Dedicated Young Man With Down Syndrome
# STORY 2: Absolute Zero

# %% [markdown]
# > ## Clean Titles

# %%
import string
@pipeline.task(depends_on=extract_titles)
def clean_titles(title):
    def _clean(title):
        title = str.lower(title)
        return ''.join(t for t in title if t not in string.punctuation)
    return(_clean(t) for t in title)

# %%
output = pipeline.run()

# %%
for x in range(3):
    print('STORY {}:'.format(x), next(output[list(output.keys())[4]]))
# Out:
# STORY 0: true goodbye ‘using truecrypt is not secure’
# STORY 1: for hire dedicated young man with down syndrome
# STORY 2: absolute zero

# %%
list(output.keys())
# Out:
# [<function __main__.file_to_json()>,
#  <function __main__.filter_stories(stories)>,
#  <function __main__.json_to_csv(filtered_stories)>,
#  <function __main__.extract_titles(csv_file)>,
#  <function __main__.clean_titles(title)>,
#  <function __main__.build_keyword_dictionary(title)>]

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
for c in string.punctuation[:5]:
    print(c,':',ord(c))
# Out:
# ! : 33
# " : 34
# # : 35
# $ : 36
# % : 37

# %% [markdown]
# > ## Build Keyword Dictionary

# %%
import stop_words
@pipeline.task(depends_on=clean_titles)
def build_keyword_dictionary(title):
    keyword_dict={}
    for t in title:
        words = t.split(' ')
        for word in words:
            if word not in stop_words.stop_words and word != '':
                if word not in keyword_dict:
                    keyword_dict[word] = 0
                keyword_dict[word] += 1
    return keyword_dict

# %%
output = pipeline.run()

# %%
for x in range(3):
    print(output[list(output.keys())[5]])
# Out:
# {'true': 5, 'goodbye': 9, '‘using': 1, 'truecrypt': 4, 'secure’': 1, 'hire': 12, 'dedicated': 6, 'young': 9, 'man': 24, 'syndrome': 3, 'absolute': 1, 'zero': 6, 'joshua': 1, 'norton': 1, 'emperor': 1, 'united': 6, 'states': 7, 'soylent': 4, 'revolution': 5, 'pleasurable': 1, 'git': 37, '20': 23, 'getting': 14, 'work': 54, 'diversity': 2, 'google': 167, 'inferring': 1, 'status': 9, 'competence': 1, 'signals': 2, 'nonconformity': 1, '2013': 65, 'pdf': 55, 'postmortem': 5, 'outage': 7, 'useast1': 2, 'apl': 2, 'glimpse': 2, 'heaven': 1, '2006': 4, 'facebook': 71, 'release': 26, 'new': 185, 'app': 57, 'feature': 12, 'listens': 2, 'users': 37, 'apple': 50, 'confirms': 3, '3': 28, 'billion': 27, 'deal': 16, 'beats': 7, 'electronics': 4, 'rubymotion': 2, '30': 15, 'sneak': 2, 'peek': 2, 'android': 34, 'support': 29, 'poverty': 4, 'prosperity': 1, 'conversation': 1, 'gates': 12, 'programming': 90, 'language': 54, 'operating': 13, 'suggesting': 1, 'migration': 1, 'bitlocker': 1, 'introducing': 30, 'socketio': 1, '10': 25, 'sourcegraph': 1, 'single': 10, 'example': 6, 'worth': 10, '1000': 6, 'lines': 12, 'documentation': 2, 'ghostery': 1, 'helps': 5, 'ad': 9, 'industry': 10, 'stop': 29, 'buying': 4, 'load': 2, 'balancers': 1, 'start': 18, 'controlling': 1, 'traffic': 6, 'flow': 2, 'software': 52, 'developeragents': 1, 'newsletter': 1, 'promote': 1, 'remote': 12, 'developers': 27, 'square': 10, 'begins': 3, 'offering': 8, 'data': 85, 'driven': 2, 'cash': 6, 'advances': 2, 'small': 9, 'businesses': 5, 'bring': 8, 'reading': 10, 'rainbow': 2, 'skeletal': 1, 'tracking': 4, 'beta': 14, 'mary': 1, 'meekers': 1, '2014': 52, 'internet': 62, 'trends': 2, 'maya': 1, 'angelou': 1, 'dies': 8, '86': 2, 'announcing': 17, 'xamarin': 2, 'developer': 36, 'indifference': 1, 'querying': 2, 'time': 48, 'series': 12, 'postgresql': 17, 'longest': 3, 'disambiguation': 1, 'page': 18, 'wikipedia': 7, 'rust': 23, 'web': 88, 'really': 14, 'germany': 3, 'dominates': 1, 'innovation': 8, 'dont': 37, 'mock': 1, 'electrooptic': 1, 'camera': 12, 'worlds': 15, 'dslr': 1, 'searchweb': 1, 'history': 16, 'disable': 3, 'does': 28, 'privacy': 16, 'selfdriving': 6, 'car': 20, 'darn': 1, 'cute': 1, 'cheats': 2, 'nginx': 8, '171': 1, 'adds': 9, 'syslog': 1, 'uber': 14, 'impact': 4, 'microsoft': 59, 'demos': 2, 'breakthrough': 4, 'realtime': 16, 'translated': 1, 'conversations': 5, 'just': 27, 'press': 3, 'designing': 7, 'vehicle': 2, 'hachetteamazon': 1, 'business': 18, 'interruption': 1, 'canadas': 1, 'pitch': 2, 'tech': 28, 'entrepreneur': 3, 'pay': 11, '80': 6, 'salaries': 2, 'experiments': 3, 'airbnb': 12, 'blow': 2, 'copyright': 5, 'trolls': 3, 'joyent': 1, 'rebooted': 1, 'operator': 3, 'error': 8, 'php': 17, 'generation': 5, 'hiring': 9, 'brokers': 1, 'use': 50, '‘billions’': 1, 'points': 4, 'profile': 1, 'americans': 10, 'sbcl': 2, '120': 2, 'released': 71, 'arm': 10, 'knod': 1, 'tiny': 7, 'http': 11, 'server': 31, 'current': 2, 'directory': 1, 'writes': 2, 'statisticians': 2, 'airfrance': 1, 'flight': 9, 'years': 33, 'crashed': 4, '1': 40, 'china': 12, 'yesterday': 3, 'vesper': 2, 'sync': 5, 'csvkit': 1, 'csv': 7, 'utilities': 3, 'includes': 1, 'csvsql': 1, 'csvgrep': 1, 'csvstat': 1, 'hipchat': 2, 'free': 64, 'unlimited': 5, 'physicists': 2, 'prove': 2, 'surprising': 1, 'rule': 8, 'threes': 4, 'y': 20, 'combinator': 17, 'founders': 15, 'earn': 1, 'static': 17, 'energy': 4, 'consumption': 2, 'analysis': 18, 'llvm': 6, 'ir': 1, 'programs': 4, 'font': 8, 'awesome': 9, 'png': 3, 'massimo': 1, 'vignelli': 1, '19312014': 1, 'headroomjs': 1, 'hide': 4, 'header': 1, 'scroll': 4, 'tmobile': 4, 'usa': 4, 'storing': 2, 'passwords': 7, 'clear': 6, 'hacker': 26, 'helped': 5, 'disrupt': 1, 'cyberattacks': 1, 'allowed': 6, 'walk': 4, 'avocado': 1, 'toolbox': 2, 'interaction': 2, 'designers': 4, 'eating': 6, 'hardware': 10, 'lessons': 17, 'building': 24, 'magical': 2, 'devices': 5, 'college': 13, 'clearly': 2, 'say': 17, 'googlebots': 1, 'recent': 3, 'improvements': 4, 'revolutionize': ...
# {'true': 5, 'goodbye': 9, '‘using': 1, 'truecrypt': 4, 'secure’': 1, 'hire': 12, 'dedicated': 6, 'young': 9, 'man': 24, 'syndrome': 3, 'absolute': 1, 'zero': 6, 'joshua': 1, 'norton': 1, 'emperor': 1, 'united': 6, 'states': 7, 'soylent': 4, 'revolution': 5, 'pleasurable': 1, 'git': 37, '20': 23, 'getting': 14, 'work': 54, 'diversity': 2, 'google': 167, 'inferring': 1, 'status': 9, 'competence': 1, 'signals': 2, 'nonconformity': 1, '2013': 65, 'pdf': 55, 'postmortem': 5, 'outage': 7, 'useast1': 2, 'apl': 2, 'glimpse': 2, 'heaven': 1, '2006': 4, 'facebook': 71, 'release': 26, 'new': 185, 'app': 57, 'feature': 12, 'listens': 2, 'users': 37, 'apple': 50, 'confirms': 3, '3': 28, 'billion': 27, 'deal': 16, 'beats': 7, 'electronics': 4, 'rubymotion': 2, '30': 15, 'sneak': 2, 'peek': 2, 'android': 34, 'support': 29, 'poverty': 4, 'prosperity': 1, 'conversation': 1, 'gates': 12, 'programming': 90, 'language': 54, 'operating': 13, 'suggesting': 1, 'migration': 1, 'bitlocker': 1, 'introducing': 30, 'socketio': 1, '10': 25, 'sourcegraph': 1, 'single': 10, 'example': 6, 'worth': 10, '1000': 6, 'lines': 12, 'documentation': 2, 'ghostery': 1, 'helps': 5, 'ad': 9, 'industry': 10, 'stop': 29, 'buying': 4, 'load': 2, 'balancers': 1, 'start': 18, 'controlling': 1, 'traffic': 6, 'flow': 2, 'software': 52, 'developeragents': 1, 'newsletter': 1, 'promote': 1, 'remote': 12, 'developers': 27, 'square': 10, 'begins': 3, 'offering': 8, 'data': 85, 'driven': 2, 'cash': 6, 'advances': 2, 'small': 9, 'businesses': 5, 'bring': 8, 'reading': 10, 'rainbow': 2, 'skeletal': 1, 'tracking': 4, 'beta': 14, 'mary': 1, 'meekers': 1, '2014': 52, 'internet': 62, 'trends': 2, 'maya': 1, 'angelou': 1, 'dies': 8, '86': 2, 'announcing': 17, 'xamarin': 2, 'developer': 36, 'indifference': 1, 'querying': 2, 'time': 48, 'series': 12, 'postgresql': 17, 'longest': 3, 'disambiguation': 1, 'page': 18, 'wikipedia': 7, 'rust': 23, 'web': 88, 'really': 14, 'germany': 3, 'dominates': 1, 'innovation': 8, 'dont': 37, 'mock': 1, 'electrooptic': 1, 'camera': 12, 'worlds': 15, 'dslr': 1, 'searchweb': 1, 'history': 16, 'disable': 3, 'does': 28, 'privacy': 16, 'selfdriving': 6, 'car': 20, 'darn': 1, 'cute': 1, 'cheats': 2, 'nginx': 8, '171': 1, 'adds': 9, 'syslog': 1, 'uber': 14, 'impact': 4, 'microsoft': 59, 'demos': 2, 'breakthrough': 4, 'realtime': 16, 'translated': 1, 'conversations': 5, 'just': 27, 'press': 3, 'designing': 7, 'vehicle': 2, 'hachetteamazon': 1, 'business': 18, 'interruption': 1, 'canadas': 1, 'pitch': 2, 'tech': 28, 'entrepreneur': 3, 'pay': 11, '80': 6, 'salaries': 2, 'experiments': 3, 'airbnb': 12, 'blow': 2, 'copyright': 5, 'trolls': 3, 'joyent': 1, 'rebooted': 1, 'operator': 3, 'error': 8, 'php': 17, 'generation': 5, 'hiring': 9, 'brokers': 1, 'use': 50, '‘billions’': 1, 'points': 4, 'profile': 1, 'americans': 10, 'sbcl': 2, '120': 2, 'released': 71, 'arm': 10, 'knod': 1, 'tiny': 7, 'http': 11, 'server': 31, 'current': 2, 'directory': 1, 'writes': 2, 'statisticians': 2, 'airfrance': 1, 'flight': 9, 'years': 33, 'crashed': 4, '1': 40, 'china': 12, 'yesterday': 3, 'vesper': 2, 'sync': 5, 'csvkit': 1, 'csv': 7, 'utilities': 3, 'includes': 1, 'csvsql': 1, 'csvgrep': 1, 'csvstat': 1, 'hipchat': 2, 'free': 64, 'unlimited': 5, 'physicists': 2, 'prove': 2, 'surprising': 1, 'rule': 8, 'threes': 4, 'y': 20, 'combinator': 17, 'founders': 15, 'earn': 1, 'static': 17, 'energy': 4, 'consumption': 2, 'analysis': 18, 'llvm': 6, 'ir': 1, 'programs': 4, 'font': 8, 'awesome': 9, 'png': 3, 'massimo': 1, 'vignelli': 1, '19312014': 1, 'headroomjs': 1, 'hide': 4, 'header': 1, 'scroll': 4, 'tmobile': 4, 'usa': 4, 'storing': 2, 'passwords': 7, 'clear': 6, 'hacker': 26, 'helped': 5, 'disrupt': 1, 'cyberattacks': 1, 'allowed': 6, 'walk': 4, 'avocado': 1, 'toolbox': 2, 'interaction': 2, 'designers': 4, 'eating': 6, 'hardware': 10, 'lessons': 17, 'building': 24, 'magical': 2, 'devices': 5, 'college': 13, 'clearly': 2, 'say': 17, 'googlebots': 1, 'recent': 3, 'improvements': 4, 'revolutionize': ...
# {'true': 5, 'goodbye': 9, '‘using': 1, 'truecrypt': 4, 'secure’': 1, 'hire': 12, 'dedicated': 6, 'young': 9, 'man': 24, 'syndrome': 3, 'absolute': 1, 'zero': 6, 'joshua': 1, 'norton': 1, 'emperor': 1, 'united': 6, 'states': 7, 'soylent': 4, 'revolution': 5, 'pleasurable': 1, 'git': 37, '20': 23, 'getting': 14, 'work': 54, 'diversity': 2, 'google': 167, 'inferring': 1, 'status': 9, 'competence': 1, 'signals': 2, 'nonconformity': 1, '2013': 65, 'pdf': 55, 'postmortem': 5, 'outage': 7, 'useast1': 2, 'apl': 2, 'glimpse': 2, 'heaven': 1, '2006': 4, 'facebook': 71, 'release': 26, 'new': 185, 'app': 57, 'feature': 12, 'listens': 2, 'users': 37, 'apple': 50, 'confirms': 3, '3': 28, 'billion': 27, 'deal': 16, 'beats': 7, 'electronics': 4, 'rubymotion': 2, '30': 15, 'sneak': 2, 'peek': 2, 'android': 34, 'support': 29, 'poverty': 4, 'prosperity': 1, 'conversation': 1, 'gates': 12, 'programming': 90, 'language': 54, 'operating': 13, 'suggesting': 1, 'migration': 1, 'bitlocker': 1, 'introducing': 30, 'socketio': 1, '10': 25, 'sourcegraph': 1, 'single': 10, 'example': 6, 'worth': 10, '1000': 6, 'lines': 12, 'documentation': 2, 'ghostery': 1, 'helps': 5, 'ad': 9, 'industry': 10, 'stop': 29, 'buying': 4, 'load': 2, 'balancers': 1, 'start': 18, 'controlling': 1, 'traffic': 6, 'flow': 2, 'software': 52, 'developeragents': 1, 'newsletter': 1, 'promote': 1, 'remote': 12, 'developers': 27, 'square': 10, 'begins': 3, 'offering': 8, 'data': 85, 'driven': 2, 'cash': 6, 'advances': 2, 'small': 9, 'businesses': 5, 'bring': 8, 'reading': 10, 'rainbow': 2, 'skeletal': 1, 'tracking': 4, 'beta': 14, 'mary': 1, 'meekers': 1, '2014': 52, 'internet': 62, 'trends': 2, 'maya': 1, 'angelou': 1, 'dies': 8, '86': 2, 'announcing': 17, 'xamarin': 2, 'developer': 36, 'indifference': 1, 'querying': 2, 'time': 48, 'series': 12, 'postgresql': 17, 'longest': 3, 'disambiguation': 1, 'page': 18, 'wikipedia': 7, 'rust': 23, 'web': 88, 'really': 14, 'germany': 3, 'dominates': 1, 'innovation': 8, 'dont': 37, 'mock': 1, 'electrooptic': 1, 'camera': 12, 'worlds': 15, 'dslr': 1, 'searchweb': 1, 'history': 16, 'disable': 3, 'does': 28, 'privacy': 16, 'selfdriving': 6, 'car': 20, 'darn': 1, 'cute': 1, 'cheats': 2, 'nginx': 8, '171': 1, 'adds': 9, 'syslog': 1, 'uber': 14, 'impact': 4, 'microsoft': 59, 'demos': 2, 'breakthrough': 4, 'realtime': 16, 'translated': 1, 'conversations': 5, 'just': 27, 'press': 3, 'designing': 7, 'vehicle': 2, 'hachetteamazon': 1, 'business': 18, 'interruption': 1, 'canadas': 1, 'pitch': 2, 'tech': 28, 'entrepreneur': 3, 'pay': 11, '80': 6, 'salaries': 2, 'experiments': 3, 'airbnb': 12, 'blow': 2, 'copyright': 5, 'trolls': 3, 'joyent': 1, 'rebooted': 1, 'operator': 3, 'error': 8, 'php': 17, 'generation': 5, 'hiring': 9, 'brokers': 1, 'use': 50, '‘billions’': 1, 'points': 4, 'profile': 1, 'americans': 10, 'sbcl': 2, '120': 2, 'released': 71, 'arm': 10, 'knod': 1, 'tiny': 7, 'http': 11, 'server': 31, 'current': 2, 'directory': 1, 'writes': 2, 'statisticians': 2, 'airfrance': 1, 'flight': 9, 'years': 33, 'crashed': 4, '1': 40, 'china': 12, 'yesterday': 3, 'vesper': 2, 'sync': 5, 'csvkit': 1, 'csv': 7, 'utilities': 3, 'includes': 1, 'csvsql': 1, 'csvgrep': 1, 'csvstat': 1, 'hipchat': 2, 'free': 64, 'unlimited': 5, 'physicists': 2, 'prove': 2, 'surprising': 1, 'rule': 8, 'threes': 4, 'y': 20, 'combinator': 17, 'founders': 15, 'earn': 1, 'static': 17, 'energy': 4, 'consumption': 2, 'analysis': 18, 'llvm': 6, 'ir': 1, 'programs': 4, 'font': 8, 'awesome': 9, 'png': 3, 'massimo': 1, 'vignelli': 1, '19312014': 1, 'headroomjs': 1, 'hide': 4, 'header': 1, 'scroll': 4, 'tmobile': 4, 'usa': 4, 'storing': 2, 'passwords': 7, 'clear': 6, 'hacker': 26, 'helped': 5, 'disrupt': 1, 'cyberattacks': 1, 'allowed': 6, 'walk': 4, 'avocado': 1, 'toolbox': 2, 'interaction': 2, 'designers': 4, 'eating': 6, 'hardware': 10, 'lessons': 17, 'building': 24, 'magical': 2, 'devices': 5, 'college': 13, 'clearly': 2, 'say': 17, 'googlebots': 1, 'recent': 3, 'improvements': 4, 'revolutionize': ...

# %% [markdown]
# > ## top 100

# %%
@pipeline.task(depends_on=build_keyword_dictionary)
def top_100(keyword_dict):
    t100=[]
    for key in sorted(keyword_dict, key=keyword_dict.get, reverse=True)[:100]:
        t100.append((key, keyword_dict[key]))
        
    return t100

# %%
output = pipeline.run()

# %%
top_100_tuples = output[list(output.keys())[6]]

# %%
top_100_tuples
# Out:
# [('new', 185),
#  ('google', 167),
#  ('bitcoin', 101),
#  ('open', 92),
#  ('programming', 90),
#  ('web', 88),
#  ('data', 85),
#  ('video', 79),
#  ('python', 75),
#  ('code', 72),
#  ('facebook', 71),
#  ('released', 71),
#  ('using', 70),
#  ('2013', 65),
#  ('javascript', 65),
#  ('free', 64),
#  ('source', 64),
#  ('game', 63),
#  ('internet', 62),
#  ('microsoft', 59),
#  ('c', 59),
#  ('linux', 58),
#  ('app', 57),
#  ('pdf', 55),
#  ('work', 54),
#  ('language', 54),
#  ('software', 52),
#  ('2014', 52),
#  ('startup', 51),
#  ('apple', 50),
#  ('use', 50),
#  ('make', 50),
#  ('time', 48),
#  ('yc', 48),
#  ('security', 48),
#  ('nsa', 45),
#  ('github', 45),
#  ('windows', 44),
#  ('world', 41),
#  ('way', 41),
#  ('like', 41),
#  ('1', 40),
#  ('project', 40),
#  ('computer', 40),
#  ('heartbleed', 40),
#  ('git', 37),
#  ('users', 37),
#  ('dont', 37),
#  ('design', 37),
#  ('ios', 37),
#  ('developer', 36),
#  ('os', 36),
#  ('twitter', 36),
#  ('ceo', 36),
#  ('vs', 36),
#  ('life', 36),
#  ('big', 35),
#  ('day', 35),
#  ('android', 34),
#  ('online', 34),
#  ('years', 33),
#  ('simple', 33),
#  ('court', 33),
#  ('guide', 32),
#  ('learning', 32),
#  ('mt', 32),
#  ('api', 32),
#  ('says', 32),
#  ('apps', 32),
#  ('browser', 32),
#  ('server', 31),
#  ('firefox', 31),
#  ('fast', 31),
#  ('gox', 31),
#  ('problem', 31),
#  ('mozilla', 31),
#  ('engine', 31),
#  ('site', 31),
#  ('introducing', 30),
#  ('amazon', 30),
#  ('year', 30),
#  ('support', 29),
#  ('stop', 29),
#  ('built', 29),
#  ('better', 29),
#  ('million', 29),
#  ('people', 29),
#  ('text', 29),
#  ('3', 28),
#  ('does', 28),
#  ('tech', 28),
#  ('development', 28),
#  ('billion', 27),
#  ('developers', 27),
#  ('just', 27),
#  ('library', 27),
#  ('did', 27),
#  ('website', 27),
#  ('money', 27),
#  ('inside', 27)]
